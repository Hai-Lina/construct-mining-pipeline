# %% [markdown]
# # CMP STEP 9: Interpreting & Comparing

# %%
NOT_LINUX = False  # set to True, if you have trouble replicating results with your operating system

# %%
# choose based on Steps 5 & 6 - Evaluation:
### UMAP final parameters ###
N_NEIGHBORS = 30
MIN_DIST = 0.01
N_COMPONENTS = 30
RANDOM_STATE = 86531

### HDBSCAN final parameters ###
MIN_SAMPLES = 30
MIN_CLUSTER_SIZE = 10

EMBEDDINGS = 'data/'

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/alina/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import warnings
warnings.filterwarnings("ignore")

import os

import pandas as pd
import numpy as np

import umap
import hdbscan 

from bokeh.plotting import figure
from bokeh.transform import factor_cmap
from bokeh.palettes import Turbo256
from bokeh.models import HoverTool
from bokeh.io import export_svg

from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords

# %%
# create folder to save solution plots
if not os.path.exists(f'solution'):
    os.makedirs(f'solution')

# %% [markdown]
# ### Load strategy texts & embeddings

# %%
# load raw strategy sentences
data = pd.read_csv(EMBEDDINGS + 'strategies_raw.csv', sep=';')
strategies = data['strategy text'].tolist()

# %%
# load strategy embeddings and convert to numpy array
strategy_embeddings = np.load(EMBEDDINGS + 'strategy_embeddings_masked.npy')

# %% [markdown]
# ### Define embedding & plotting functions

# %%
def umap_hdbscan(embeds=strategy_embeddings,
                 n_neighbors=N_NEIGHBORS,
                 min_dist=MIN_DIST,
                 n_components=N_COMPONENTS,
                 random_state=RANDOM_STATE,
                 min_cluster_size=MIN_CLUSTER_SIZE,
                 min_samples=MIN_SAMPLES):
    if NOT_LINUX == True:
        umap_embed_fin = np.load(EMBEDDINGS + f'not_linux/umap_embeddings_seed-{RANDOM_STATE}-(final).npy')
    else:
        umap_fin = umap.UMAP(n_neighbors=n_neighbors,
                             min_dist=min_dist,
                             n_components=n_components,
                             metric='cosine',
                             random_state=random_state).fit(embeds)
                             # gives majority of cluster solutions of 1.000 different UMAP seeds

        umap_embed_fin = umap_fin.transform(embeds)

    hdbscan_fin = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size,
                                  min_samples=min_samples,
                                  metric='euclidean')

    hdbscan_fin.fit(umap_embed_fin)
    
    return hdbscan_fin


def umap_2D(embeds=strategy_embeddings):
    # reduce dimensions further to 2D for plotting
    umap_2D = umap.UMAP(n_neighbors=N_NEIGHBORS,
                        min_dist=MIN_DIST,
                        n_components=2,
                        metric='cosine',
                        random_state=RANDOM_STATE).fit(embeds)

    umap_2D_embed = umap_2D.transform(embeds)
    
    return umap_2D_embed


def plot_ER_atlas(umap_2D, hdbscan, x_range, y_range):
    # create df with plotting data for bokeh interactive plot
    clusters = np.delete(umap_2D, np.where(hdbscan.labels_ == -1)[0], axis=0)
    cluster_labels = hdbscan.labels_[hdbscan.labels_ != -1]
    noise = np.delete(umap_2D, np.where(hdbscan.labels_ != -1)[0], axis=0)

    cluster_df = pd.DataFrame()
    cluster_df['x'] = clusters[:,0]
    cluster_df['y'] = clusters[:,1]
    cluster_df['labels'] = [str(label) for label in cluster_labels]
    cluster_df['strategy_text'] = np.delete(strategies, np.where(hdbscan.labels_ == -1)[0])

    noise_df = pd.DataFrame()
    noise_df['x'] = noise[:,0]
    noise_df['y'] = noise[:,1]
    noise_df['strategy_text'] = np.delete(strategies, np.where(hdbscan.labels_ != -1)[0])
    
    # create interactive bokeh plot of ER strategy clusters
    no_clusters = (max(cluster_labels) + 1)
    step = int(np.floor(len(Turbo256) / no_clusters)) 
    colors = Turbo256[::step][:no_clusters]
    
    p = figure(x_range=x_range, y_range=y_range, width=900, height=600, tools=['pan', 'wheel_zoom', 'reset', 'hover'])
               #, title='Landscape of Emotion Regulation Strategies')
    p.scatter(x='x', y='y', source=cluster_df, size=4, fill_alpha=0.5, color=factor_cmap('labels', colors, list(set(cluster_df['labels']))))
    p.scatter(x='x', y='y', source=noise_df, size=4, fill_alpha=0.5, color='#B3CCCC', marker='cross')
    p.xgrid.visible = False
    p.ygrid.visible = False
    p.xaxis.visible = False
    p.yaxis.visible = False
    p.title.align = 'center'
    p.background_fill_color = '#F0F5F5'
    hover = p.select(dict(type=HoverTool))
    hover.tooltips = [('Text', '@strategy_text')]
    
    p.output_backend = "svg"
    p.background_fill_color = None
    p.border_fill_color = None
        
    return p

# %% [markdown]
# ### Compute final UMAP & HDBSCAN combination and plot

# %%
hdbscan_fin = umap_hdbscan(embeds=strategy_embeddings)
# cross-check number of clusters (37) & unclustered points (3067)
print(f'Number of clusters: {max(hdbscan_fin.labels_ + 1)}')
print(f'Number of unclustered points: {list(hdbscan_fin.labels_).count(-1)}')
umap_2D_masked = umap_2D(embeds=strategy_embeddings)
# Out:
# Number of clusters: 37
# Number of unclustered points: 3067

# %%
h = plot_ER_atlas(umap_2D_masked, hdbscan_fin, (-4, 7), (-4.5, 6.5))
# export_svg(h, filename="solution/ER_atlas.svg")
# Out:
# ['solution/ER_atlas.svg']

# %% [markdown]
# ### Inspect clusters for interpretation

# %%
# create dataframe with sentences and cluster labels
label_df = pd.DataFrame(strategies, columns=['Strategy'])
label_df['Label'] = hdbscan_fin.labels_
# label_df.to_csv('strategies_labels.csv', index=False)

# %%
CLUSTER = 0  # print sentences for cluster CLUSTER

print(f'CLUSTER {CLUSTER}: \n')
for i in label_df[label_df.Label == CLUSTER]['Strategy'].tolist():
    print(i)
# Out:
# CLUSTER 0:
#
# Gefuehle der anderen Person mitteilen
# eine Person, der man vertraut davon erzaehlen
# koerperliches Training
# Ich finde Loesungen unabhaengig von diesem Kollegen.
# Ich mache meinem Aerger ihm gegenueber Luft.
# Ich aendere zukuenftige Plaene, sodass sie moeglichst ohne diesen Kollegen funktionieren.
# fruehere Zeit ansetzen
# Atemuebungen machen
# Ich kann ihm bei seiner Aufgabe helfen, die zur besagten Info fuehrt.
# Ich kann die Situation meinem Chef erklaeren.
# Ich kann meinen Zeitplan ein wenig aendern.
# Pause machen & spaeter weitermachen
# Falls er immer zu spaet dran ist mit jmd anderem zusammenarbeiten
# Dinge machen fuer die man normalerweise zu wenig Freizeit hat
# ich lasse den Kollegen wissen wie veraergert ich bin
# Fragen, warum nicht, koennte plausible Gruende (haben) geben
# Erklaeren, dass er es das naechste Mal frueher anfangen soll bzw. An andere denken muss.
# fuer das naechste Mal planen, dich nicht von diesem Kollegen abhaengig zu machen
# in mich gehen & ueberdenken, ob ich es geschafft haette, die Infos rechtzeitig weiterzugeben (wenn ich in der Situation von meinem Kollegen gewesen waer)
# dem Kollegen klar machen, dass er meinen Zeitplan durch seine Uzuverlaessigkeit kaputt gemacht hat
# versuchen Kompromiss bezueglich des Ortes zu finden
# Waehrenddessen mit einem Freund reden (telefonieren)
# Kurzfristige Angst > Sport machen, um dennoch klar abwaegen zu koennen
# mit Freunden darueber reden, das relativiert das ganze
# oefter kuerzere Fluege machen, langsam steigern
# Musik hoeren, anders Ablenken
# darueber mit jemandem Reden
# Vor den Spiegel stellen und sagen, dass man es schaffen wird, schon schlimmeres ueberstanden hat
# Ich koennte ein Seminar gegen Flugangst besuchen.
# Ich koennte mich ueber Methoden informieren, die mich vor und waehrend des Fluges beruhigen.
# Ich koennte mit anderen Menschen reden, die ebenso unter Flugangst leiden, mich informieren.
# Ich koennte mich ueber die Sicherheit von Flugreisen informieren.
# Ich spreche mit Freunden ueber die Angst
# ich mache mir klar, dass der Job wichtig genug ist, um dafuer Opfer zu bringen (bzw.) meine Grenzen zu durchbrechen
# ich frage eine Person, der ich vertraue oder das Flugpersonal fuer Unterstuetzung
# Mit meinen Angehoeringen darueber sprechen
# Ein hoffnungsvolles Lied hoeren
# Schoene Erinnerungen m. d. Person(en) hervorrufen
# Mit Freunden/Familie darueber reden
# Weinen nicht vermeiden/unterdruecken
# 1x drueber schlafen
# mit Leuten darueber Reden, auch mit Betroffenen
# Ich rede mit meiner Familie darueber.
# Ich informiere mich ueber die Krankheit, ich kann ihr eventuell helfen bzw. ihr Leiden besser machen.
# Ich versuche ihr, die Zeit dort so angenehm wie moeglich zu bereiten.
# Ich schicke ihr meine besten Wuensche fuer die Genesung.
# Gespraech mit Partner o. Freunden suchen
# Ich rede mit Anderen ueber meine Gefuehle
# Ich starte eine Hilfsinitiative fuer Menschen mit dieser Krankheit
# Ich informiere mich ueber die Krankheit
# Ich bete fuer sie.
# Ich weine mich aus, um danach klarer denken zu koennen.
# Wenn Ichs durch dritte erfahre, ruf ich persoenlich zum Reden nochmal an.
# Ich rede mit Freunden zum Verarbeiten drueber
# ich informiere mich ueber die Krankheit & Therapien
# ich plane einen Ueberraschung fuer sie, um sie aufzuheitern
# Nach Gruenden fuer die Meinung fragen
# koerperliches Training
# „Zurueckschiessen“, wenn da …
# haerter trainieren/***
# darueber Reden, auch mit ihm > Verbesserung
# Ich hoere nicht auf sie
# Ich konfrontiere sie und sage ihnen meine Meinung und wie ich mich fuehle
# Ich laestere auch ueber sie
# Ich rede mit Freunden darueber > zweite MEinung
# Ich frage sie, wie ich es besser machen koennte.
# Ich uebe alleine nach dem Training weiter
# ich rede auch schlecht ueber sie
# die anderen um Hilfe bitten die eigenen Faehigkeiten zu verbessern
# An mir arbeiten, meine Faehigkeiten verbessern
# Atemuebungen
# Witze drueber
# Mit Freunden darueber reden
# eigene Motivation finden und verstaerken
# darueber Reden
# darueber nachdenken, wie man selber frueher war
# Ich sage mir, dass ich Erfahrung auf anderen Gebieten habe, aber meine Faehigkeiten mit der Zeit verbessere.
# Ich rede mit einem Freund/einer Freundin darueber.
# In hoeherem Alter hat man mehr Ahnung von der Praxis
# viele Dinge die junge Stud. noch lernen muessen weisst du schon
# Gespraech zu Studentinnen suchen - vermutlich denken die genau umgekehrt
# Ich strenge mich so gut an wie moeglich
# Ich rede mit Freunden ueber meine Aengste
# Jeder hat Staerken und Schwaechen, nicht unterkriegen lasen!
# ich hoere auf mich mit den anderen zu vergleichen, das ist toxisch
# ich frage andere nach Hilfe, wenn ich merke, dass sie etwas koennen & ich nicht
# ich arbeite umso haerter, um auch auf ihrem Level zu sein
# Mit Freunden/Familie darueber sprechen
# Mir versichern, dass es jedem passieren koennte
# mit meinem Chef darueber reden/Reden!
# Ich reflektiere meine Arbeit, denke an moegliche Fehler, v.a. aber was ich gut gemacht habe.
# Ich stuerze mich in ander Arbeit und sorge somit fuer Ablenkung.
# Supervision machen (Gruppe - um auch v. anderen zu hoeren wie sie mit sowas umgehen)
# Gespraeche mit Freunden/Partner
# Ich rede mit anderen Klienten ueber meine Leistung
# Ich werde nur noch Klienten, die meine Zeit schaetzen annehmen/weiterbetreuen
# Ich frage den Klienten, warum er es mir nicht persoenlich sagt.
# Ich erklaere dem Klienten, dass ich mit seinen Anforderungen mein Bestes gebe.
# Ich bin wuetend und schrei meinen Klienten an.
# meine höhere Instanz (Chef) ist zufrieden, das ist alles was zaehlen sollte
# ich will es nicht persoenlich nehmen
# naechstes Mal walze ich den Klient auf jmd anderen ab
# Ich versuche den Grund dafuer zu finden.
# Beweise sammeln und dadurch Erklaerung fuer die Verspaetung bringen
# sich ueber die fehlende Erwaehnung beschweren
# haerter arbeiten, um die Zeit wenigstens ein bisschen gut zu machen
# bei der zustaendigen Person fuer die Betriebsmittel beschweren
# Mit Familie/Freunde darueber sprechen
# Der zustaendigen Person meine Gefuehle mitteilen
# koerperliches Training
# Ich versuche den Grund fuer die verspaeteten Betriebsmitel zu finden und fuer die Zukunft zu beheben.
# Ich stelle sicher, dass alle den Grund fuer den schlechten Arbeitsfortschritt kennen.
# Fragen, warum es nicht erwaehnt wird
# immer wieder alles ueberpruefen
# frueh genug beginnen
# Zaehne zusammenbeissen und ab jetzt hart daran arbeiten
# Situationsanalyse um in Zukunft bessert reagieren zu koennen
# Ich sorge fuer Aufklaerung.
# Ich sorge dafuer, dass der Zugang zu den Betriebsmitteln garantiert wird und hole die Arbeit nach.
# Ich rede mit einer/m Kollegin/Kollege darueber.
# man arbeitet noch sein ganzes Leben was ist also dabei, wenn diese Arbeit etwas laenger dauert?
# Wenn andere Parteien involviert sind muss man auch in Zukunft damit rechnen, dass es zu Verzoegerungen kommt
# Ich spreche mit den Vorgesetzten darueber
# Ich brauche beim naechsten Projekt mehr Zeit
# Ich spreche mit Freunden darueber
# Ich erklaere der Ansprechperson, wie die Situation aussah und bitte um Verstaendnis
# ich mache klar, dass ich das Beste tat, was im Rahmen meiner Moeglichkeiten lag
# Familie benachrichtigen sich unauffaellig zu verhalten
# Die bloede Tante nicht einladen
# Ich lade enge Freunde unter den Verwandten schon fuer etwas frueher ein.
# Ich bin in regem Kontakt mit meiner Familie bzgl der Feier und uebergebe einige Aufgaben.
# Ich arbeite daran der Angst, ein Gefuehl der Freude und Vorfreude ueber die Feier entgegenzusetzen.
# jeden fuer etwas einteilen > muss es nicht alleine schaffen
# darueber Reden
# frueh genug mit der Planung beginnen
# Musik hoeren, damit s lustig wird (Vorbereitung + Party)
# Ich schreibe zuvor eine Nachricht an sie, die meine Bedenken erklaert.
# nicht alles muss perfekt sein > andere koennen sich auf einer nicht perfekten Party an der der Gastgeber gelassen teilnehmen kann besser amuesieren als wenn alles ist & der Gastgeber gestresst & nervoes ist > eigene Ansprueche an sich selbst zurueckschrauben
# Musik hoeren waehrend der Vorbereitung
# Ich spreche mit Freunden ueber meine Nervositaet
# Ich bitte meine Mutter um Rat, da sie das oefters macht. (einladen)
# Ich suche Spiele heraus, mit denen man sie beschaeftigen koennte.
# Ich ueberlege mir Gespraechsthemen, die ich die Runde werfen koennte.
# Ich koche, um alle somit fuer eine Weile zu beschaeftigen.
# Neue Beschaeftigung fuer Freitags finden
# Ihm von deinen Gefuehlen erzaehlen
# Ich verstaerke meinen sozialen Kreis in der Firma mit den Leuten, die ich laufend sehe.
# Ich probiere ihn zu vergessen und nuetze die freigewordene Zeit fuer andere Dinge, die ich gerne mache.
# Ich frage ob ihm ein anderer Tag besser passen wuerde.
# Ich rufe ihn an um ueber die Vorkommnisse zu sprechen.
# Ich denke nach ueber die Ursachen, dass
# Kollegen fragen, ob dies weiterhin moeglich waere
# sich Freitags mit anderen Kollegen ins Cafe setzen & ueber Arbeit reden
# Ich fuehre die Tradition mit einem anderen Kollegen weiter
# sage ihm wie ich mich fuehle
# mache andere Aktivitaeten mit ihm
# spreche mit Freunden darueber
# Ich besuche seine Abteilung in meiner Pause und rede mal persoenlich mit ihm.
# suche mir ein neues Hobby, damit ich nicht ich noch nach der Arbeit ueber die Arbeit reden muss

# %%
# 0 : --- .34
# 1 : substances (medication) .96
# 2 : situational control (flight anxiety item 2) .96
# 3 : 'fliegen' .94
# 4 : distraction .79
# 5 : relaxation techniques .97
# 6 : therapy .91
# 7 : situational control (sick relatives item 3) .88
# 8 : --- [refocusing?] .65!
# 9 : suppression .86
# 10: 'anrufen' .75
# 11: eating & drinking 1.00
# 12: substances (alcohol) .94
# 13: 'anfreunden' .96
# 14: situational control (colleague gone item 9) .95
# 15: 'Café' .75
# 16: information seeking .91
# 17: withdrawal .88
# 18: 'Angst' .85
# 19: situational control (house warming party item 8) .89
# 20: emotional expression 1.00
# 21: instrumental support .85
# 22: --- .44
# 23: self-enhancement .76
# 24: situational control (sport team item 4) .83
# 25: situational control (university item 5) .88
# 26: situational control (resources item 7) 1.00
# 27: social support .85
# 28: social support 1.00
# 29: social support .96
# 30: situational control (information item 1) .81
# 31: emotional expression .94
# 32: 'beschweren' 1.00
# 33: reappraisal .79
# 34: 'Begriffe aus Arbeitskontext' (Bericht, Betriebsmittel, Klient, Kunde, ...) .80
# 35: instrumental support .90
# 36: instrumental support 1.00

# %% [markdown]
# ### Extract cluster top words table with c-TF_IDF (class-based TF-IFD)
# (see BERTopic tutorial)

# %%
### DEFINE TOP WORDS HELPER FUNCTIONS ###

GERMAN_STOP = stopwords.words('german')


def c_tf_idf(documents, m):
    # documents: single document of concatenated documents per class
    # m: original number of documents
    count = CountVectorizer(stop_words=GERMAN_STOP).fit(documents)
    t = count.transform(documents).toarray()
    w = t.sum(axis=1)
    tf = np.divide(t.T, w)
    sum_t = t.sum(axis=0)
    idf = np.log(np.divide(m, sum_t)).reshape(-1, 1)
    tf_idf = np.multiply(tf, idf)

    return tf_idf, count


def extract_topic_topwords(tf_idf, count, docs_per_topic, n=20):
    # tf_idf: c_tf_idf
    # count: CountVectorizer
    # docs_per_topic: c_tf_idf dataframe
    # n: number of topwords to be returned (dictionary with {topic_labels: top_words})
    words = count.get_feature_names()
    labels = list(docs_per_topic.Topic)
    tf_idf_transposed = tf_idf.T
    indices = tf_idf_transposed.argsort()[:, -n:]
    top_n_words = {label: [(words[j], tf_idf_transposed[i][j]) for j in indices[i]][::-1] for i, label in enumerate(labels)}
    
    return top_n_words

def top_words_table(hdbscan, n=10):
    """extracts top n words for each cluster based on a tf-idf cluster representation"""
    """FOR VISUALIZATION PURPOSES"""
    # create single document with all documents (=strategy texts) in single cluster
    docs_df = pd.DataFrame(strategies, columns=["Doc"])
    docs_df['Topic'] = hdbscan.labels_
    docs_per_topic = docs_df.groupby(['Topic'], as_index = False).agg({'Doc': ' '.join})

    # extract topwords
    tf_idf, count = c_tf_idf(docs_per_topic.Doc.values, m=len(strategies))
    top_n_words = extract_topic_topwords(tf_idf, count, docs_per_topic, n=n)
    
    top_words_table = pd.DataFrame(columns=['Cluster', 'Top Words'])

    for i, j in zip(top_n_words, range(len(top_n_words))):
        top_words_table.loc[j] = [i, ' '.join([j[0] for j in top_n_words[i]])]

    return top_words_table

# %%
# compute and display top words table
pd.set_option('display.max_colwidth', 1000)
table = top_words_table(hdbscan_fin)
table
# Out:
#     Cluster  \
# 0        -1
# 1         0
# 2         1
# 3         2
# 4         3
# 5         4
# 6         5
# 7         6
# 8         7
# 9         8
# 10        9
# 11       10
# 12       11
# 13       12
# 14       13
# 15       14
# 16       15
# 17       16
# 18       17
# 19       18
# 20       19
# 21       20
# 22       21
# 23       22
# 24       23
# 25       24
# 26       25
# 27       26
# 28       27
# 29       28
# 30       29
# 31       30
# 32       31
# 33       32
# 34       33
# 35       34
# 36       35
# 37       36
#
#                                                                                                                     Top Words
# 0                                                   kollegen versuche frage klienten rede mehr freunden fragen situation chef
# 1                                                       darueber fuer ueber koennte reden freunden rede koennen hoeren arbeit
# 2       medikamente nehme beruhigungstabletten beruhigungsmittel nehmen tabletten besorge beruhigende flug beruhigungstropfen
# 3                                  zug alternativen suche verkehrsmittel schiff bahn fahren transportmöglichkeiten ort suchen
# 4                                         fliegen flug fliege angst statistiken trotzdem person sicherheit informiere einfach
# 5                                                      ablenken lenke ab abzulenken musik ablenkung film sport schauen schaue
# 6                      entspannen meditiere pause entspannungstechniken entspannungsübungen tief atmen mache atme atemübungen
# 7                        therapie flugangst therapeuten gehe gehen überwinden psychologen psychologische therapieren versuche
# 8                                         besuchen krankenhaus besuche verwandten fahre verwandte besuch fahren sofort person
# 9                                                        zeit spass erledigen sinnvoll dinge macht derweil tun hobbies sachen
# 10                         ignorieren vergessen ignoriere versuche vergesse versuchen weitermachen verdränge darüber gedanken
# 11                                   rufe anrufen kontakt telefonieren telefoniere freundin kollegen halten beste regelmässig
# 12                                                            essen esse schokolade eis gutes kaffee gehen trinken kochen gut
# 13                                                   trinke alkohol glas betrinke trinken wein vorher weinen entspannung bier
# 14                           anfreunden freunde kollegen freundschaften neue freunden befreunden treffe anzufreunden versuche
# 15                                                   treffen termin tag kollegen frage ausmachen finden trotzdem möchte neuen
# 16                                                      cafe gehen gehe freitags alleine allein kaffee kollegen mehr einladen
# 17  krankheit informieren informiere erkundige behandlungsmöglichkeiten arzt heilungschancen recherchieren krank beschäftigen
# 18                                                            ab wechseln wechsle job team lehne vertrag studium suchen suche
# 19                                        angst ängste spreche familie freunden sprechen aengste reden nervosität freundinnen
# 20                                                                  bereite plane tag gut planen vorbereiten do to liste plan
# 21                                              trauer weinen weine lasse freien lauf traurigkeit gefühle verkrieche gefühlen
# 22                                                  hilfe rat bitten helfen fragen unterstützung freunde bitte kollegen holen
# 23                                      zeit geschenk schöne verwandten person verbringen erleben momente erinnerungen zeiten
# 24                                                fähigkeiten stärken eigenen augen bewusst gut mehr erfahrung erfolge eigene
# 25                                       härter trainiere mehr verbessern trainieren besser anstrengen versuche beim leistung
# 26                                   lerne lernen mehr lerngruppen nachhilfe lerngruppe vorlesungen bilden tutorien beitreten
# 27                   zeitplan zwischenbericht überarbeiten anpassen ändern korrigieren neuen neu optimieren umzustrukturieren
# 28                                      reden darüber freunden jemandem jemanden sprechen unterhalten drüber auslassen jemand
# 29                                                 darüber rede spreche freunden freundin freund erzähle davon guten kollegin
# 30                                       familie reden freunden darüber sprechen verwandten fremden vertrauten person anrufen
# 31                                  information beschaffen informationen selber bekommen versuchen info mal versuche wichtige
# 32                                                        ärger lasse wut frust rauslassen sport luft beim boxen rauszulassen
# 33                                 beschwere beschweren beim chef kollegen freunden zuständigen darüber vorgesetzten aufregen
# 34                                                             schlimm schuld gut daran sage bewusst sagen perfekt klar schon
# 35                                                bericht beschwerde zuständigen grund person frage klienten wer weise klient
# 36                                 chef situation vorgesetzten erkläre sache darüber spreche vorgesetzte aufzuklären berichte
# 37                                      chef trainer rede ansprechen darauf aussprechen aussprache erneut besprechen bescheid
